# %%
import numpy as np 
import matplotlib.pyplot as plt 

import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rcParams['font.size'] = 12
plt.rc('axes', labelsize=20) 
plt.set_cmap('coolwarm')

# %%
gradient = np.arange(0,10,0.1)
q_2 = gradient**2/700
q_3 = gradient**3/10000
bg = gradient**1.3/100

plt.figure(figsize=(8, 8))
plt.plot(gradient,bg,'k')
plt.plot(gradient,q_2,'r--')
plt.plot(gradient,q_3,'b:')
plt.ylabel('$\langle |u(z) - u^{\mathrm{Nusselt}}(z)| \\rangle$')
plt.xlabel('$[ \partial_z u ]_{z=h}$ ')
# Out:
# Text(0.5, 0, '$[ \\partial_z u ]_{z=h}$ ')
